# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhant419/Data-Science/blob/master/ML_google.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs=np.array([-1,0,1,2,3,4],dtype=int)
ys=np.array([-2,1,4,7,10,13],dtype=int)

# %%
model.fit(xs, ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6129e-07
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5799e-07
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5473e-07
# Epoch 4/500
# 1/1 [==============================] - 0s 947us/step - loss: 1.5154e-07
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4842e-07
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4539e-07
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4239e-07
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3948e-07
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3658e-07
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3384e-07
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3103e-07
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[30.999973]]
